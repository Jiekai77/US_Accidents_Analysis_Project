# %%
#clean data 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_csv('US_Accidents_Dec20.csv')

# %%
data.head()
# Out:
#     ID    Source    TMC  Severity           Start_Time             End_Time  \
# 0  A-1  MapQuest  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  MapQuest  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  MapQuest  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  MapQuest  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  MapQuest  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  ...  Roundabout Station   Stop  \
# 0  39.865147 -84.058723      NaN      NaN  ...       False   False  False
# 1  39.928059 -82.831184      NaN      NaN  ...       False   False  False
# 2  39.063148 -84.032608      NaN      NaN  ...       False   False  False
# 3  39.747753 -84.205582      NaN      NaN  ...       False   False  False
# 4  39.627781 -84.188354      NaN      NaN  ...       False   False  False
#
# ...

# %%
# check missing values of each column for training dataset
data.isnull()
data.isnull().sum()
# Out:
# ID                             0
# Source                         0
# TMC                      1516064
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  2716477
# End_Lng                  2716477
# Distance(mi)                   0
# Description                    2
# Number                   2687949
# Street                         0
# Side                           0
# City                         137
# County                         0
# State                          0
# Zipcode                     1292
# Country                        0
# Timezone                    4615
# Airport_Code                8973
# Weather_Timestamp          62644
# Temperature(F)             89900
# Wind_Chill(F)            1896001
# Humidity(%)                95467
# Pressure(in)               76384
# Visibility(mi)             98668
# ...

# %%
len(data)
# Out:
# 4232541

# %%
# if the number of missing values in the column is greater than half number of the rows, then we could delete this column
data.drop(['End_Lat'], axis=1, inplace=True)
data.drop(['End_Lng'], axis=1, inplace=True)
data.drop(['Number'], axis=1, inplace=True)

# %%
# drop insignificant columns 
#data.drop(['Street', 'Airport_Code', 'Source'], axis=1, inplace=True)# drop insignificant columns 
data.drop(['Timezone', 'Civil_Twilight', 'Nautical_Twilight','Astronomical_Twilight'],axis=1, inplace=True)

# %%
#data.drop(['Weather_Timestamp'],axis=1, inplace=True)
data.drop(['Side'],axis=1, inplace=True)

# %%
data
# Out:
#                 ID    TMC  Severity           Start_Time             End_Time  \
# 0              A-1  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1              A-2  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2              A-3  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3              A-4  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4              A-5  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
# ...            ...    ...       ...                  ...                  ...
# 4232536  A-4239402    NaN         2  2019-08-23 18:03:25  2019-08-23 18:32:01
# 4232537  A-4239403    NaN         2  2019-08-23 19:11:30  2019-08-23 19:38:23
# 4232538  A-4239404    NaN         2  2019-08-23 19:00:21  2019-08-23 19:28:49
# 4232539  A-4239405    NaN         2  2019-08-23 19:00:21  2019-08-23 19:29:42
# 4232540  A-4239406    NaN         2  2019-08-23 18:52:06  2019-08-23 19:21:31
#
# ...

# %%
data['TMC'].fillna(data['TMC'].mean(),inplace=True)

# %%
data['City'].fillna(data['City'].mode(),inplace=True)

# %%
data['Zipcode'].fillna(data['Zipcode'].mode(),inplace=True)

# %%
for column in ['Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)','Pressure(in)', 'Visibility(mi)','Wind_Speed(mph)','Precipitation(in)']:
    data[column].fillna(data[column].mean(), inplace=True)

# %%
for column in ['Weather_Condition', 'Wind_Direction', 'Sunrise_Sunset']:
    data[column].fillna(data[column].mode()[0], inplace=True)

# %%
data
# Out:
#                 ID         TMC  Severity           Start_Time  \
# 0              A-1  201.000000         3  2016-02-08 05:46:00
# 1              A-2  201.000000         2  2016-02-08 06:07:59
# 2              A-3  201.000000         2  2016-02-08 06:49:27
# 3              A-4  201.000000         3  2016-02-08 07:23:34
# 4              A-5  201.000000         2  2016-02-08 07:39:07
# ...            ...         ...       ...                  ...
# 4232536  A-4239402  208.351719         2  2019-08-23 18:03:25
# 4232537  A-4239403  208.351719         2  2019-08-23 19:11:30
# 4232538  A-4239404  208.351719         2  2019-08-23 19:00:21
# 4232539  A-4239405  208.351719         2  2019-08-23 19:00:21
# 4232540  A-4239406  208.351719         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng  Distance(mi)  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723         0.010
# 1        2016-02-08 06:37:59  39.928059  -82.831184         0.010
# ...

# %%
result= data
result.to_csv('Cleaned data from Sophia')
